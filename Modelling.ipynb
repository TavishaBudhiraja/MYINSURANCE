# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.countplot(x = "sex", data = df, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x = "children", data = df, hue='smoker')
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
sns.countplot(x = "region", data = df, hue='smoker')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
plt.figure(figsize=(15,9))
sns.boxplot(y="smoker", x="charges", data =  df , orient="h",hue='sex' )
# Out:
# <Axes: xlabel='charges', ylabel='smoker'>

# %%
plt.figure(figsize=(15,9))
sns.distplot(df["age"])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7008\818861763.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["age"])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.lmplot(x="age", y="charges", hue="smoker", data=df, height = 7)

# %%
plt.figure(figsize=(15,9))
sns.distplot(df["bmi"])
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_7008\3399277495.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["bmi"])
# <Axes: xlabel='bmi', ylabel='Density'>

# %%
plt.figure(figsize=(15,9))
ax = sns.scatterplot(x='bmi',y='charges',data=df,hue='smoker')

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df.corr(numeric_only = True),annot=True)
# Out:
# <Axes: >

# %%
print(df['sex'].value_counts())
print(df['smoker'].value_counts())
print(df['region'].value_counts())
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# age - std scaler
# sex - label encoding
# bmi - std scaler
# children - normal
# smoker - label
# region - hot encoding but used label encoding 
# charges - target

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["sex"] = le.fit_transform(df["sex"])

# %%
df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
print(df['sex'].value_counts())
# Out:
# sex
# 1    676
# 0    662
# Name: count, dtype: int64

# %%
df["smoker"] = le.fit_transform(df["smoker"])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
print(df['smoker'].value_counts())
# Out:
# smoker
# 0    1064
# 1     274
# Name: count, dtype: int64

# %%
print(df['region'].value_counts())
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
d = le.fit_transform(df["region"])

# %%
dd = pd.DataFrame(d)

# %%
dd.value_counts()
# Out:
# 0
# 2    364
# 1    325
# 3    325
# 0    324
# Name: count, dtype: int64

# %%
df['region'] = d

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
x = df[['age', 'sex', 'bmi','children', 'smoker','region']]
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#         5.55973703e+03,  3.12410753e+04,  9.55295762e+03,  1.16108430e+04,
#         1.53496491e+04,  5.94260823e+03,  1.08412665e+04,  1.07287888e+04,
#         1.09104655e+04,  5.04155599e+03,  9.42873421e+03,  8.24474965e+03,
#         3.32344346e+03,  7.98139506e+03,  8.09931892e+03,  4.10480755e+03,
#         1.72603014e+04,  3.41778968e+04,  4.49691297e+03,  1.92902639e+03,
#         5.35301695e+03,  9.35100116e+03,  1.87503629e+03, -1.48819711e+03,
#         4.39512757e+03,  1.20311373e+04,  3.64410404e+04,  1.54613860e+04,
#         1.09558069e+04,  5.58183556e+03,  8.24405854e+03,  4.38024844e+03,
#         1.35456975e+04,  3.26738849e+04,  4.84056405e+03,  2.52643793e+04,
#         5.56921050e+03,  3.58467294e+04,  1.14026207e+04,  1.35417206e+04,
#         1.30217532e+04,  4.27990477e+03,  4.79665046e+03,  2.48978087e+04,
#         1.27048395e+04,  5.68636348e+03,  1.08464943e+04,  1.02618150e+04,
#         4.44953399e+03,  4.03980807e+04,  7.73265901e+03,  9.47956581e+03,
#         3.23106671e+04,  3.62630237e+04,  6.20230313e+03,  4.34277801e+03,
#         3.34952763e+04,  9.81086985e+03,  9.29246048e+03,  5.82372664e+03,
#         9.67718365e+03,  6.15685144e+03,  1.14749757e+04,  1.54979309e+04,
#         6.51045984e+03,  1.10844273e+04,  2.80644444e+04,  9.55366057e+03,
#         6.62487860e+03,  1.30916011e+04,  3.26939306e+04,  1.22232106e+04,
#         1.26739093e+04,  7.32191759e+03,  1.00272060e+04,  6.28154591e+03,
#         3.59089347e+04,  1.27288737e+04,  8.11699009e+03,  4.71624650e+03,
#         4.62562974e+03,  9.50974697e+03,  1.72099060e+04,  8.36843670e+03,
#         6.95599646e+03,  3.20434816e+04,  4.20351295e+03,  1.43331933e+04,
#         6.26097342e+03,  1.27815853e+04,  3.87800541e+03,  2.56932922e+03,
#         8.62918819e+03,  3.66656858e+04,  1.13083220e+04,  1.30501324e+04,
#         8.75602506e+03,  3.31961554e+04,  5.61606349e+03,  3.13642210e+03,
#         2.22756440e+03,  1.36516862e+04,  3.25043047e+01,  1.11548900e+04,
#         1.18000205e+04,  3.59811890e+04,  5.37729132e+03,  3.98623021e+03,
#         1.25248589e+04,  9.81547355e+03,  9.53828084e+03,  5.82929765e+03])

# %%
predictions = lm.predict(x_test)

# %%
plt.scatter(y_test,predictions)

# %%
print(predictions[0:5]) 
print(y_test[0:5])
# Out:
# [11195.42951446  3320.71771472 10573.94458221 27473.59767071
#   6540.68715994]
# 44       6079.67150
# 134      2457.21115
# 980     25517.11363
# 618     34439.85590
# 1238     6985.50695
# Name: charges, dtype: float64

# %%
df_final = pd.DataFrame({'Predicted':predictions,'Actual':y_test})

# %%
df_final = df_final.reset_index()

# %%
df_final = df_final.drop(['index'],axis=1)

# %%
fig= plt.figure(figsize=(16,8))
plt.plot(df_final[:50])
plt.legend(['Real','Prediction'])

# %%
fig= plt.figure(figsize=(16,8))
sns.jointplot(x='Actual',y='Predicted',data=df_final,kind='reg',)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3920.536943887805
# MSE: 31667189.32516578
# RMSE: 5627.360777946068

# %%
import pickle

# %%
with open("model.pkl",'wb') as f:
    pickle.dump(lm,f)
